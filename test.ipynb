# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\Fintra_AI\.venv\Lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in d:\Fintra_AI\.venv\Lib\site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\Fintra_AI\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\Fintra_AI\.venv\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in d:\Fintra_AI\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in d:\Fintra_AI\.venv\Lib\site-packages (3.11.1)
# Requirement already satisfied: seaborn in d:\Fintra_AI\.venv\Lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\Fintra_AI\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\Fintra_AI\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in d:\Fintra_AI\.venv\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\Fintra_AI\.venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in d:\Fintra_AI\.venv\Lib\site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in d:\Fintra_AI\.venv\Lib\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in d:\Fintra_AI\.venv\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in d:\Fintra_AI\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\Fintra_AI\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in d:\Fintra_AI\.venv\Lib\site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: tzdata in d:\Fintra_AI\.venv\Lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in d:\Fintra_AI\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

test_df = pd.read_csv("financial_transactions_test.csv")

print(test_df.head())
print(test_df.shape)
print(test_df.columns)
# Out:
#                               Transaction_Text       Label
# 0  Mobile EMI payment - INR 45866 - Ref 955127         EMI
# 1  Education loan EMI - INR 32772 - Ref 858630         EMI
# 2       Bike loan EMI - INR 12852 - Ref 259771         EMI
# 3    PPF contribution - INR 10392 - Ref 505075  Investment
# 4     NPS contribution - INR 3583 - Ref 580994  Investment
# (1000, 2)
# Index(['Transaction_Text', 'Label'], dtype='str')

# %% [markdown]
# EDA

# %%
print("\nMissing values:")
print(test_df.isnull().sum())
# Out:
# Missing values:
# Transaction_Text    0
# Label               0
# dtype: int64

# %%
print("\nDuplicate rows:")
print(test_df.duplicated().sum())
# Out:
# Duplicate rows:
# 0

# %%
print("\nClass distribution:")
print(test_df["Label"].value_counts())
# Out:
# Class distribution:
# Label
# Food          217
# EMI           204
# Shopping      204
# Investment    189
# Travel        186
# Name: count, dtype: int64
